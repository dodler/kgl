# %%
import os
import os.path as osp
import matplotlib.pyplot as plt
import random
import cv2
import numpy as np
import pandas as pd

from PIL import Image
import tifffile as tiff

from tqdm import *
tqdm=tqdm_notebook

# %%
target_dir='/var/ssd_1t/kaggle_panda/'

# %%
os.listdir(target_dir)
# Out:
# ['train_images_2048',
#  'sample_submission.csv',
#  'test.csv',
#  'train_label_masks_crop_4096',
#  'train_label_masks',
#  'train.csv']

# %%
images=os.listdir(osp.join(target_dir, 'train_images_2048'))
images=[osp.join(target_dir, 'train_images_2048',k) for k in images]
images=[k for k in images if k.endswith('0.png')]

# %%
n=3
m=3
fig=plt.figure(figsize=(10,10))
for i in range(n*m):
    img_path=random.choice(images)
    img=Image.open(img_path)
    fig.add_subplot(n,m,i+1)
    plt.imshow(img)

# %%
masks=os.listdir(osp.join(target_dir, 'train_label_masks'))
masks=[osp.join(osp.join(target_dir, 'train_label_masks',k)) for k in masks]

# %%
train=pd.read_csv(osp.join(target_dir, 'train.csv'))

# %%
sub=pd.read_csv(osp.join(target_dir, 'sample_submission.csv'))
